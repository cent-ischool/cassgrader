# %%
import subprocess
import glob
import os

notebooks = os.path.join(os.getcwd(),"**/*.ipynb")
for filespec in glob.glob(notebooks,recursive=True)[:]:
    process = subprocess.run(["jupyter","trust", filespec],stdout=subprocess.PIPE,stderr=subprocess.PIPE)
    print(f"Trusting: {process.stdout.decode('utf-8').strip()}")
    if process.returncode != 0:
        print(f"Error: {process.stderr.decode('utf-8').strip()}")
# Out:
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/GetAssignments.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/TrustAll.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/UpdateCassGrader.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/oldTeacherTools.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/Grader.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/BlackboardGradebook.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/RunGrader.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/SetCourse.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/GradingTools.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/admin/Admin.ipynb
# Trusting:
# Error: Traceback (most recent call last):
#   File "/opt/conda/bin/jupyter-trust", line 10, in <module>
#     sys.exit(TrustNotebookApp.launch_instance())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/jupyter_core/application.py", line 281, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "/opt/conda/lib/python3.11/site-packages/traitlets/config/application.py", line 1077, in launch_instance
#     app.start()
#   File "/opt/conda/lib/python3.11/site-packages/nbformat/sign.py", line 638, in start
#     self.sign_notebook_file(notebook_path)
#   File "/opt/conda/lib/python3.11/site-packages/nbformat/sign.py", line 605, in sign_notebook_file
#     with open(notebook_path, encoding="utf-8") as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# IsADirectoryError: [Errno 21] Is a directory: '/home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/LAB-Lists.ipynb'
# Trusting:
# Error: Traceback (most recent call last):
#   File "/opt/conda/bin/jupyter-trust", line 10, in <module>
#     sys.exit(TrustNotebookApp.launch_instance())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/jupyter_core/application.py", line 281, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "/opt/conda/lib/python3.11/site-packages/traitlets/config/application.py", line 1077, in launch_instance
#     app.start()
#   File "/opt/conda/lib/python3.11/site-packages/nbformat/sign.py", line 638, in start
#     self.sign_notebook_file(notebook_path)
#   File "/opt/conda/lib/python3.11/site-packages/nbformat/sign.py", line 605, in sign_notebook_file
#     with open(notebook_path, encoding="utf-8") as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# IsADirectoryError: [Errno 21] Is a directory: '/home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/HW-Lists.ipynb'
# Trusting:
# Error: Traceback (most recent call last):
#   File "/opt/conda/bin/jupyter-trust", line 10, in <module>
#     sys.exit(TrustNotebookApp.launch_instance())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/jupyter_core/application.py", line 281, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "/opt/conda/lib/python3.11/site-packages/traitlets/config/application.py", line 1077, in launch_instance
#     app.start()
#   File "/opt/conda/lib/python3.11/site-packages/nbformat/sign.py", line 638, in start
#     self.sign_notebook_file(notebook_path)
#   File "/opt/conda/lib/python3.11/site-packages/nbformat/sign.py", line 605, in sign_notebook_file
#     with open(notebook_path, encoding="utf-8") as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# IsADirectoryError: [Errno 21] Is a directory: '/home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/SmallGroup-Lists.ipynb'
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/LAB-Lists.ipynb/tecatala@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/LAB-Lists.ipynb/bsulli10@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/LAB-Lists.ipynb/mjosep13@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/LAB-Lists.ipynb/bsaltman@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/LAB-Lists.ipynb/jgonza69@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/LAB-Lists.ipynb/wyliving@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/LAB-Lists.ipynb/cjviglio@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/LAB-Lists.ipynb/cfflecke@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/LAB-Lists.ipynb/mking29@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/LAB-Lists.ipynb/kramir10@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/LAB-Lists.ipynb/ryaddo@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/LAB-Lists.ipynb/cazides@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/LAB-Lists.ipynb/jvonters@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/LAB-Lists.ipynb/aknigro@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/LAB-Lists.ipynb/jcallaha@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/LAB-Lists.ipynb/pbsteven@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/LAB-Lists.ipynb/avallen@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/LAB-Lists.ipynb/tamoses@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/LAB-Lists.ipynb/relopezr@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/LAB-Lists.ipynb/cgordo13@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/LAB-Lists.ipynb/netramda@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/LAB-Lists.ipynb/kfrzepal@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/LAB-Lists.ipynb/amorri33@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/HW-Lists.ipynb/tecatala@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/HW-Lists.ipynb/mjosep13@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/HW-Lists.ipynb/bsaltman@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/HW-Lists.ipynb/jgonza69@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/HW-Lists.ipynb/cfflecke@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/HW-Lists.ipynb/mking29@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/HW-Lists.ipynb/ryaddo@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/HW-Lists.ipynb/jvonters@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/HW-Lists.ipynb/aknigro@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/HW-Lists.ipynb/jcallaha@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/HW-Lists.ipynb/pbsteven@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/HW-Lists.ipynb/avallen@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/HW-Lists.ipynb/tamoses@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/HW-Lists.ipynb/jolear03@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/HW-Lists.ipynb/relopezr@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/HW-Lists.ipynb/cgordo13@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/HW-Lists.ipynb/netramda@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/HW-Lists.ipynb/kfrzepal@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/08-Lists/HW-Lists.ipynb/amorri33@syr.edu.ipynb
# Trusting:
# Error: Traceback (most recent call last):
#   File "/opt/conda/bin/jupyter-trust", line 10, in <module>
#     sys.exit(TrustNotebookApp.launch_instance())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/jupyter_core/application.py", line 281, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "/opt/conda/lib/python3.11/site-packages/traitlets/config/application.py", line 1077, in launch_instance
#     app.start()
#   File "/opt/conda/lib/python3.11/site-packages/nbformat/sign.py", line 638, in start
#     self.sign_notebook_file(notebook_path)
#   File "/opt/conda/lib/python3.11/site-packages/nbformat/sign.py", line 605, in sign_notebook_file
#     with open(notebook_path, encoding="utf-8") as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# IsADirectoryError: [Errno 21] Is a directory: '/home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/SmallGroup-PandasI.ipynb'
# Trusting:
# Error: Traceback (most recent call last):
#   File "/opt/conda/bin/jupyter-trust", line 10, in <module>
#     sys.exit(TrustNotebookApp.launch_instance())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/jupyter_core/application.py", line 281, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "/opt/conda/lib/python3.11/site-packages/traitlets/config/application.py", line 1077, in launch_instance
#     app.start()
#   File "/opt/conda/lib/python3.11/site-packages/nbformat/sign.py", line 638, in start
#     self.sign_notebook_file(notebook_path)
#   File "/opt/conda/lib/python3.11/site-packages/nbformat/sign.py", line 605, in sign_notebook_file
#     with open(notebook_path, encoding="utf-8") as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# IsADirectoryError: [Errno 21] Is a directory: '/home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/LAB-PandasI.ipynb'
# Trusting:
# Error: Traceback (most recent call last):
#   File "/opt/conda/bin/jupyter-trust", line 10, in <module>
#     sys.exit(TrustNotebookApp.launch_instance())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/jupyter_core/application.py", line 281, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "/opt/conda/lib/python3.11/site-packages/traitlets/config/application.py", line 1077, in launch_instance
#     app.start()
#   File "/opt/conda/lib/python3.11/site-packages/nbformat/sign.py", line 638, in start
#     self.sign_notebook_file(notebook_path)
#   File "/opt/conda/lib/python3.11/site-packages/nbformat/sign.py", line 605, in sign_notebook_file
#     with open(notebook_path, encoding="utf-8") as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# IsADirectoryError: [Errno 21] Is a directory: '/home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/HW-PandasI.ipynb'
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/SmallGroup-PandasI.ipynb/tecatala@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/SmallGroup-PandasI.ipynb/bsulli10@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/SmallGroup-PandasI.ipynb/mjosep13@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/SmallGroup-PandasI.ipynb/bsaltman@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/SmallGroup-PandasI.ipynb/jgonza69@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/SmallGroup-PandasI.ipynb/wyliving@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/SmallGroup-PandasI.ipynb/cjviglio@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/SmallGroup-PandasI.ipynb/cfflecke@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/SmallGroup-PandasI.ipynb/acclause@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/SmallGroup-PandasI.ipynb/mking29@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/SmallGroup-PandasI.ipynb/kramir10@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/SmallGroup-PandasI.ipynb/ryaddo@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/SmallGroup-PandasI.ipynb/cazides@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/SmallGroup-PandasI.ipynb/jvonters@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/SmallGroup-PandasI.ipynb/aknigro@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/SmallGroup-PandasI.ipynb/jcallaha@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/SmallGroup-PandasI.ipynb/pbsteven@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/SmallGroup-PandasI.ipynb/avallen@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/SmallGroup-PandasI.ipynb/tamoses@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/SmallGroup-PandasI.ipynb/jolear03@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/SmallGroup-PandasI.ipynb/cgordo13@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/SmallGroup-PandasI.ipynb/netramda@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/SmallGroup-PandasI.ipynb/kfrzepal@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/SmallGroup-PandasI.ipynb/amorri33@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/LAB-PandasI.ipynb/tecatala@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/LAB-PandasI.ipynb/bsulli10@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/LAB-PandasI.ipynb/mjosep13@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/LAB-PandasI.ipynb/bsaltman@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/LAB-PandasI.ipynb/jgonza69@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/LAB-PandasI.ipynb/cjviglio@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/LAB-PandasI.ipynb/cfflecke@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/LAB-PandasI.ipynb/mking29@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/LAB-PandasI.ipynb/kramir10@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/LAB-PandasI.ipynb/ryaddo@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/LAB-PandasI.ipynb/cazides@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/LAB-PandasI.ipynb/jvonters@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/LAB-PandasI.ipynb/aknigro@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/LAB-PandasI.ipynb/jcallaha@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/LAB-PandasI.ipynb/avallen@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/LAB-PandasI.ipynb/tamoses@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/LAB-PandasI.ipynb/amorri33@syr.edu-71b56fc2fd431b887eab5826a7af4ecd.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/LAB-PandasI.ipynb/jolear03@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/LAB-PandasI.ipynb/relopezr@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/LAB-PandasI.ipynb/cgordo13@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/LAB-PandasI.ipynb/kfrzepal@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/LAB-PandasI.ipynb/amorri33@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/HW-PandasI.ipynb/tecatala@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/HW-PandasI.ipynb/bsulli10@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/HW-PandasI.ipynb/mjosep13@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/HW-PandasI.ipynb/jgonza69@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/HW-PandasI.ipynb/cjviglio@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/HW-PandasI.ipynb/cfflecke@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/HW-PandasI.ipynb/mking29@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/HW-PandasI.ipynb/kramir10@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/HW-PandasI.ipynb/ryaddo@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/HW-PandasI.ipynb/cazides@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/HW-PandasI.ipynb/jvonters@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/HW-PandasI.ipynb/aknigro@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/HW-PandasI.ipynb/jcallaha@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/HW-PandasI.ipynb/avallen@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/HW-PandasI.ipynb/tamoses@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/HW-PandasI.ipynb/relopezr@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/HW-PandasI.ipynb/cgordo13@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/HW-PandasI.ipynb/netramda@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/HW-PandasI.ipynb/kfrzepal@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/10-Pandas-I/HW-PandasI.ipynb/amorri33@syr.edu.ipynb
# Trusting:
# Error: Traceback (most recent call last):
#   File "/opt/conda/bin/jupyter-trust", line 10, in <module>
#     sys.exit(TrustNotebookApp.launch_instance())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/jupyter_core/application.py", line 281, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "/opt/conda/lib/python3.11/site-packages/traitlets/config/application.py", line 1077, in launch_instance
#     app.start()
#   File "/opt/conda/lib/python3.11/site-packages/nbformat/sign.py", line 638, in start
#     self.sign_notebook_file(notebook_path)
#   File "/opt/conda/lib/python3.11/site-packages/nbformat/sign.py", line 605, in sign_notebook_file
#     with open(notebook_path, encoding="utf-8") as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# IsADirectoryError: [Errno 21] Is a directory: '/home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/HW-Variables.ipynb'
# Trusting:
# Error: Traceback (most recent call last):
#   File "/opt/conda/bin/jupyter-trust", line 10, in <module>
#     sys.exit(TrustNotebookApp.launch_instance())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/jupyter_core/application.py", line 281, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "/opt/conda/lib/python3.11/site-packages/traitlets/config/application.py", line 1077, in launch_instance
#     app.start()
#   File "/opt/conda/lib/python3.11/site-packages/nbformat/sign.py", line 638, in start
#     self.sign_notebook_file(notebook_path)
#   File "/opt/conda/lib/python3.11/site-packages/nbformat/sign.py", line 605, in sign_notebook_file
#     with open(notebook_path, encoding="utf-8") as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# IsADirectoryError: [Errno 21] Is a directory: '/home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/LAB-Variables.ipynb'
# Trusting:
# Error: Traceback (most recent call last):
#   File "/opt/conda/bin/jupyter-trust", line 10, in <module>
#     sys.exit(TrustNotebookApp.launch_instance())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/jupyter_core/application.py", line 281, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "/opt/conda/lib/python3.11/site-packages/traitlets/config/application.py", line 1077, in launch_instance
#     app.start()
#   File "/opt/conda/lib/python3.11/site-packages/nbformat/sign.py", line 638, in start
#     self.sign_notebook_file(notebook_path)
#   File "/opt/conda/lib/python3.11/site-packages/nbformat/sign.py", line 605, in sign_notebook_file
#     with open(notebook_path, encoding="utf-8") as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# IsADirectoryError: [Errno 21] Is a directory: '/home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/SmallGroup-Variables.ipynb'
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/HW-Variables.ipynb/tecatala@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/HW-Variables.ipynb/bsulli10@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/HW-Variables.ipynb/mjosep13@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/HW-Variables.ipynb/bsaltman@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/HW-Variables.ipynb/jgonza69@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/HW-Variables.ipynb/wyliving@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/HW-Variables.ipynb/cjviglio@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/HW-Variables.ipynb/cfflecke@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/HW-Variables.ipynb/mking29@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/HW-Variables.ipynb/kramir10@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/HW-Variables.ipynb/cazides@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/HW-Variables.ipynb/jvonters@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/HW-Variables.ipynb/aknigro@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/HW-Variables.ipynb/jcallaha@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/HW-Variables.ipynb/pbsteven@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/HW-Variables.ipynb/avallen@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/HW-Variables.ipynb/tamoses@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/HW-Variables.ipynb/jolear03@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/HW-Variables.ipynb/relopezr@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/HW-Variables.ipynb/cgordo13@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/HW-Variables.ipynb/netramda@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/HW-Variables.ipynb/kfrzepal@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/HW-Variables.ipynb/amorri33@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/LAB-Variables.ipynb/tecatala@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/LAB-Variables.ipynb/bsulli10@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/LAB-Variables.ipynb/mjosep13@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/LAB-Variables.ipynb/bsaltman@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/LAB-Variables.ipynb/jgonza69@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/LAB-Variables.ipynb/wyliving@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/LAB-Variables.ipynb/cjviglio@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/LAB-Variables.ipynb/cfflecke@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/LAB-Variables.ipynb/mking29@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/LAB-Variables.ipynb/kramir10@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/LAB-Variables.ipynb/ryaddo@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/LAB-Variables.ipynb/cazides@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/LAB-Variables.ipynb/jvonters@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/LAB-Variables.ipynb/aknigro@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/LAB-Variables.ipynb/jcallaha@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/LAB-Variables.ipynb/pbsteven@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/LAB-Variables.ipynb/avallen@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/LAB-Variables.ipynb/tamoses@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/LAB-Variables.ipynb/jolear03@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/LAB-Variables.ipynb/relopezr@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/LAB-Variables.ipynb/cgordo13@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/LAB-Variables.ipynb/netramda@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/LAB-Variables.ipynb/kfrzepal@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/LAB-Variables.ipynb/amorri33@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/SmallGroup-Variables.ipynb/tecatala@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/SmallGroup-Variables.ipynb/mafudge@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/SmallGroup-Variables.ipynb/bsulli10@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/SmallGroup-Variables.ipynb/mjosep13@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/SmallGroup-Variables.ipynb/bsaltman@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/SmallGroup-Variables.ipynb/jgonza69@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/SmallGroup-Variables.ipynb/wyliving@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/SmallGroup-Variables.ipynb/cjviglio@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/SmallGroup-Variables.ipynb/cfflecke@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/SmallGroup-Variables.ipynb/mking29@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/SmallGroup-Variables.ipynb/kramir10@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/SmallGroup-Variables.ipynb/ryaddo@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/SmallGroup-Variables.ipynb/cazides@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/SmallGroup-Variables.ipynb/jvonters@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/SmallGroup-Variables.ipynb/aknigro@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/SmallGroup-Variables.ipynb/jcallaha@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/SmallGroup-Variables.ipynb/pbsteven@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/SmallGroup-Variables.ipynb/avallen@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/SmallGroup-Variables.ipynb/tamoses@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/SmallGroup-Variables.ipynb/jolear03@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/SmallGroup-Variables.ipynb/relopezr@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/SmallGroup-Variables.ipynb/cgordo13@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/SmallGroup-Variables.ipynb/netramda@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/SmallGroup-Variables.ipynb/kfrzepal@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/02-Variables/SmallGroup-Variables.ipynb/amorri33@syr.edu.ipynb
# Trusting:
# Error: Traceback (most recent call last):
#   File "/opt/conda/bin/jupyter-trust", line 10, in <module>
#     sys.exit(TrustNotebookApp.launch_instance())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/jupyter_core/application.py", line 281, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "/opt/conda/lib/python3.11/site-packages/traitlets/config/application.py", line 1077, in launch_instance
#     app.start()
#   File "/opt/conda/lib/python3.11/site-packages/nbformat/sign.py", line 638, in start
#     self.sign_notebook_file(notebook_path)
#   File "/opt/conda/lib/python3.11/site-packages/nbformat/sign.py", line 605, in sign_notebook_file
#     with open(notebook_path, encoding="utf-8") as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# IsADirectoryError: [Errno 21] Is a directory: '/home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/LAB-Functions.ipynb'
# Trusting:
# Error: Traceback (most recent call last):
#   File "/opt/conda/bin/jupyter-trust", line 10, in <module>
#     sys.exit(TrustNotebookApp.launch_instance())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/jupyter_core/application.py", line 281, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "/opt/conda/lib/python3.11/site-packages/traitlets/config/application.py", line 1077, in launch_instance
#     app.start()
#   File "/opt/conda/lib/python3.11/site-packages/nbformat/sign.py", line 638, in start
#     self.sign_notebook_file(notebook_path)
#   File "/opt/conda/lib/python3.11/site-packages/nbformat/sign.py", line 605, in sign_notebook_file
#     with open(notebook_path, encoding="utf-8") as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# IsADirectoryError: [Errno 21] Is a directory: '/home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/SmallGroup-Functions.ipynb'
# Trusting:
# Error: Traceback (most recent call last):
#   File "/opt/conda/bin/jupyter-trust", line 10, in <module>
#     sys.exit(TrustNotebookApp.launch_instance())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/jupyter_core/application.py", line 281, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "/opt/conda/lib/python3.11/site-packages/traitlets/config/application.py", line 1077, in launch_instance
#     app.start()
#   File "/opt/conda/lib/python3.11/site-packages/nbformat/sign.py", line 638, in start
#     self.sign_notebook_file(notebook_path)
#   File "/opt/conda/lib/python3.11/site-packages/nbformat/sign.py", line 605, in sign_notebook_file
#     with open(notebook_path, encoding="utf-8") as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# IsADirectoryError: [Errno 21] Is a directory: '/home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/HW-Functions.ipynb'
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/LAB-Functions.ipynb/tecatala@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/LAB-Functions.ipynb/bsulli10@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/LAB-Functions.ipynb/mjosep13@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/LAB-Functions.ipynb/bsaltman@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/LAB-Functions.ipynb/jgonza69@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/LAB-Functions.ipynb/wyliving@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/LAB-Functions.ipynb/cjviglio@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/LAB-Functions.ipynb/cfflecke@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/LAB-Functions.ipynb/mking29@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/LAB-Functions.ipynb/kramir10@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/LAB-Functions.ipynb/ryaddo@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/LAB-Functions.ipynb/jvonters@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/LAB-Functions.ipynb/aknigro@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/LAB-Functions.ipynb/jcallaha@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/LAB-Functions.ipynb/pbsteven@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/LAB-Functions.ipynb/avallen@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/LAB-Functions.ipynb/tamoses@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/LAB-Functions.ipynb/jolear03@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/LAB-Functions.ipynb/relopezr@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/LAB-Functions.ipynb/cgordo13@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/LAB-Functions.ipynb/netramda@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/LAB-Functions.ipynb/kfrzepal@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/LAB-Functions.ipynb/amorri33@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/SmallGroup-Functions.ipynb/tecatala@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/SmallGroup-Functions.ipynb/bsulli10@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/SmallGroup-Functions.ipynb/mjosep13@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/SmallGroup-Functions.ipynb/bsaltman@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/SmallGroup-Functions.ipynb/jgonza69@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/SmallGroup-Functions.ipynb/wyliving@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/SmallGroup-Functions.ipynb/cjviglio@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/SmallGroup-Functions.ipynb/cfflecke@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/SmallGroup-Functions.ipynb/mking29@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/SmallGroup-Functions.ipynb/kramir10@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/SmallGroup-Functions.ipynb/ryaddo@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/SmallGroup-Functions.ipynb/cazides@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/SmallGroup-Functions.ipynb/jvonters@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/SmallGroup-Functions.ipynb/aknigro@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/SmallGroup-Functions.ipynb/jcallaha@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/SmallGroup-Functions.ipynb/pbsteven@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/SmallGroup-Functions.ipynb/avallen@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/SmallGroup-Functions.ipynb/tamoses@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/SmallGroup-Functions.ipynb/jolear03@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/05-Functions/SmallGroup-Functions.ipynb/relopezr@syr.edu.ipynb
# ...
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# IsADirectoryError: [Errno 21] Is a directory: '/home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/HW-Dictionaries.ipynb'
# Trusting:
# Error: Traceback (most recent call last):
#   File "/opt/conda/bin/jupyter-trust", line 10, in <module>
#     sys.exit(TrustNotebookApp.launch_instance())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/jupyter_core/application.py", line 281, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "/opt/conda/lib/python3.11/site-packages/traitlets/config/application.py", line 1077, in launch_instance
#     app.start()
#   File "/opt/conda/lib/python3.11/site-packages/nbformat/sign.py", line 638, in start
#     self.sign_notebook_file(notebook_path)
#   File "/opt/conda/lib/python3.11/site-packages/nbformat/sign.py", line 605, in sign_notebook_file
#     with open(notebook_path, encoding="utf-8") as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# IsADirectoryError: [Errno 21] Is a directory: '/home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/LAB-Dictionaries.ipynb'
# Trusting:
# Error: Traceback (most recent call last):
#   File "/opt/conda/bin/jupyter-trust", line 10, in <module>
#     sys.exit(TrustNotebookApp.launch_instance())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/jupyter_core/application.py", line 281, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "/opt/conda/lib/python3.11/site-packages/traitlets/config/application.py", line 1077, in launch_instance
#     app.start()
#   File "/opt/conda/lib/python3.11/site-packages/nbformat/sign.py", line 638, in start
#     self.sign_notebook_file(notebook_path)
#   File "/opt/conda/lib/python3.11/site-packages/nbformat/sign.py", line 605, in sign_notebook_file
#     with open(notebook_path, encoding="utf-8") as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# IsADirectoryError: [Errno 21] Is a directory: '/home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/SmallGroup-Dictionaries.ipynb'
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/HW-Dictionaries.ipynb/tecatala@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/HW-Dictionaries.ipynb/bsulli10@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/HW-Dictionaries.ipynb/mjosep13@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/HW-Dictionaries.ipynb/bsaltman@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/HW-Dictionaries.ipynb/jgonza69@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/HW-Dictionaries.ipynb/cjviglio@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/HW-Dictionaries.ipynb/cfflecke@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/HW-Dictionaries.ipynb/mking29@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/HW-Dictionaries.ipynb/ryaddo@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/HW-Dictionaries.ipynb/jvonters@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/HW-Dictionaries.ipynb/aknigro@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/HW-Dictionaries.ipynb/jcallaha@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/HW-Dictionaries.ipynb/pbsteven@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/HW-Dictionaries.ipynb/avallen@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/HW-Dictionaries.ipynb/tamoses@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/HW-Dictionaries.ipynb/relopezr@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/HW-Dictionaries.ipynb/cgordo13@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/HW-Dictionaries.ipynb/netramda@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/HW-Dictionaries.ipynb/kfrzepal@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/HW-Dictionaries.ipynb/amorri33@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/LAB-Dictionaries.ipynb/tecatala@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/LAB-Dictionaries.ipynb/bsulli10@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/LAB-Dictionaries.ipynb/mjosep13@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/LAB-Dictionaries.ipynb/bsaltman@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/LAB-Dictionaries.ipynb/jgonza69@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/LAB-Dictionaries.ipynb/wyliving@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/LAB-Dictionaries.ipynb/cjviglio@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/LAB-Dictionaries.ipynb/mking29@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/LAB-Dictionaries.ipynb/kramir10@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/LAB-Dictionaries.ipynb/ryaddo@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/LAB-Dictionaries.ipynb/cazides@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/LAB-Dictionaries.ipynb/jvonters@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/LAB-Dictionaries.ipynb/aknigro@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/LAB-Dictionaries.ipynb/jcallaha@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/LAB-Dictionaries.ipynb/pbsteven@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/LAB-Dictionaries.ipynb/avallen@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/LAB-Dictionaries.ipynb/tamoses@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/LAB-Dictionaries.ipynb/jolear03@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/LAB-Dictionaries.ipynb/relopezr@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/LAB-Dictionaries.ipynb/cgordo13@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/LAB-Dictionaries.ipynb/netramda@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/LAB-Dictionaries.ipynb/kfrzepal@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/LAB-Dictionaries.ipynb/amorri33@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/SmallGroup-Dictionaries.ipynb/tecatala@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/SmallGroup-Dictionaries.ipynb/bsulli10@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/SmallGroup-Dictionaries.ipynb/mjosep13@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/SmallGroup-Dictionaries.ipynb/jgonza69@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/SmallGroup-Dictionaries.ipynb/cjviglio@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/SmallGroup-Dictionaries.ipynb/cfflecke@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/SmallGroup-Dictionaries.ipynb/acclause@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/SmallGroup-Dictionaries.ipynb/mking29@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/SmallGroup-Dictionaries.ipynb/kramir10@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/SmallGroup-Dictionaries.ipynb/ryaddo@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/SmallGroup-Dictionaries.ipynb/cazides@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/SmallGroup-Dictionaries.ipynb/jvonters@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/SmallGroup-Dictionaries.ipynb/aknigro@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/SmallGroup-Dictionaries.ipynb/jcallaha@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/SmallGroup-Dictionaries.ipynb/pbsteven@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/SmallGroup-Dictionaries.ipynb/avallen@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/SmallGroup-Dictionaries.ipynb/tamoses@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/SmallGroup-Dictionaries.ipynb/jolear03@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/SmallGroup-Dictionaries.ipynb/relopezr@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/SmallGroup-Dictionaries.ipynb/cgordo13@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/SmallGroup-Dictionaries.ipynb/netramda@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/SmallGroup-Dictionaries.ipynb/kfrzepal@syr.edu.ipynb
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/ist256-spring2024/mafudge@syr.edu/09-Dictionaries/SmallGroup-Dictionaries.ipynb/amorri33@syr.edu.ipynb
# Trusting:
# Error: Traceback (most recent call last):
#   File "/opt/conda/bin/jupyter-trust", line 10, in <module>
#     sys.exit(TrustNotebookApp.launch_instance())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/jupyter_core/application.py", line 281, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "/opt/conda/lib/python3.11/site-packages/traitlets/config/application.py", line 1077, in launch_instance
#     app.start()
#   File "/opt/conda/lib/python3.11/site-packages/nbformat/sign.py", line 638, in start
#     self.sign_notebook_file(notebook_path)
#   File "/opt/conda/lib/python3.11/site-packages/nbformat/sign.py", line 605, in sign_notebook_file
#     with open(notebook_path, encoding="utf-8") as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# IsADirectoryError: [Errno 21] Is a directory: '/home/jovyan/library/cassgrader/fetched/tst101-spring2024/mafudge@syr.edu/A/A2.ipynb'
# Trusting:
# Error: Traceback (most recent call last):
#   File "/opt/conda/bin/jupyter-trust", line 10, in <module>
#     sys.exit(TrustNotebookApp.launch_instance())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/jupyter_core/application.py", line 281, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "/opt/conda/lib/python3.11/site-packages/traitlets/config/application.py", line 1077, in launch_instance
#     app.start()
#   File "/opt/conda/lib/python3.11/site-packages/nbformat/sign.py", line 638, in start
#     self.sign_notebook_file(notebook_path)
#   File "/opt/conda/lib/python3.11/site-packages/nbformat/sign.py", line 605, in sign_notebook_file
#     with open(notebook_path, encoding="utf-8") as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# IsADirectoryError: [Errno 21] Is a directory: '/home/jovyan/library/cassgrader/fetched/tst101-spring2024/mafudge@syr.edu/A/A1.ipynb'
# Trusting: Signing notebook: /home/jovyan/library/cassgrader/fetched/tst101-spring2024/mafudge@syr.edu/A/A2.ipynb/mafudge@syr.edu.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/templates/SmallGroup.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/templates/MF-HW.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/templates/Homework.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/templates/MF-P1.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/templates/MF-LAB.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/templates/MF-SG.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/templates/README.ipynb
# Trusting: Notebook already signed: /home/jovyan/library/cassgrader/templates/Lab.ipynb
